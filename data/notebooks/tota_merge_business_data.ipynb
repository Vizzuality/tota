# %% [markdown]
# # Join Business data tables
# This notebook serves as a data pipeline to merge data sources for TOTA business, and check the result. This is likely a one-time operation.

# %%
import pandas as pd 
import numpy as np
import math

# %% [markdown]
# ### 1.1. Load reference dataset (Sonja's list)

# %%
sheet_id = "1GUqBfjwIlXa_vJDSCqLAfeNwtnRulzZfzRsLA7Y5qIQ"
sheet_name = "Sonja_list"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
sonja_df = pd.read_csv(url)
sonja_df['Company ID'] = np.int64(sonja_df['Company ID'])
sonja_df.drop(columns = list(sonja_df.filter(regex='Unnamed')), inplace=True)

sonja_df['Company ID'] = sonja_df['Company ID'].apply(lambda x: str(x))
sonja_df['Company ID'].replace(to_replace='-9223372036854775808', value=np.nan, inplace=True)

sonja_df
# Out:
#      Nr (Sonjas List)  Company ID               Name of Business/Organization  \
# 0                 1.0  3887918904                       Moon Curser Vineyards
# 1                 2.0  4381261090                 Adega On 45Th Estate Winery
# 2                 3.0  4381342221                             Lastella Winery
# 3                 4.0  4381289423                              Nk'Mip Cellars
# 4                 5.0  4373591998      Bordertown Vineyards And Estate Winery
# ..                ...         ...                                         ...
# 322               NaN  5065356135                        Terravista Vineyards
# 323               NaN  4381282467               The Bx Press Cidery & Orchard
# 324               NaN  4381287827                    The Cove Lakeside Resort
# 325               NaN  5105018331                     Tinhorn Creek Vineyards
# 326               NaN  4077835569  Ubc Conferences And Accommodation Okanagan
#
#                     Website                   Street          City  \
# 0            mooncurser.com  3628 British Columbia 3       Osoyoos
# 1            www.winebc.com         7311-45Th Street       Osoyoos
# 2           www.lastella.ca          8123 148 Avenue       Osoyoos
# 3      www.nkmipcellars.com  1400 Rancher Creek Road       Osoyoos
# 4      bordertownwinery.com       9140 - 92Nd Avenue       Osoyoos
# ..                      ...                      ...           ...
# 322                     NaN                      NaN           NaN
# 323  http://thebxpress.com/    4667 East Vernon Road        Vernon
# 324    www.covelakeside.com       4205 Gellatly Road  West Kelowna
# 325             miradoro.ca     537 Tinhorn Creek Rd        Oliver
# 326  www.ubcconferences.com  1290 International Mews       Kelowna
#
#                Region Postal Code Country     Tourism Region  ...  \
# 0    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 1    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 2    British Columbia     V0H 1V0  Canada  Thompson Okanagan  ...
# 3    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 4    British Columbia     V0H 1V2  Canada  Thompson Okanagan  ...
# ..                ...         ...     ...                ...  ...
# 322  British Columbia         NaN  Canada  Thompson Okanagan  ...
# 323  British Columbia         NaN  Canada  Thompson Okanagan  ...
# 324  British Columbia     V4T 2K4  Canada  Thompson Okanagan  ...
# 325  British Columbia     V0H 1T1  Canada  Thompson Okanagan  ...
# 326  British Columbia     V1V 1V8  Canada  Thompson Okanagan  ...
#
#                       Tags Indigenous Tourism Biosphere Program Member  \
# 0    Wineries/Destilleries              False                    False
# 1    Wineries/Destilleries              False                    False
# 2    Wineries/Destilleries              False                    False
# 3    Wineries/Destilleries              False                    False
# 4    Wineries/Destilleries              False                    False
# ..                     ...                ...                      ...
# 322  Wineries/Destilleries              False                    False
# 323                    NaN              False                    False
# 324                    NaN              False                    False
# 325  Wineries/Destilleries              False                    False
# 326                    NaN              False                    False
#
#     Accessibility  Number of Employees  Year Founded  Show_on_platform  \
# 0            True                 10.0        2003.0              True
# 1            True                  NaN        2011.0              True
# 2            True                 50.0        2005.0              True
# 3            True                  NaN        2003.0              True
# 4            True                  NaN           NaN              True
# ..            ...                  ...           ...               ...
# 322          True                  NaN           NaN              True
# 323          True                  NaN           NaN              True
# 324          True                 50.0        2006.0              True
# 325          True                  NaN        1993.0              True
# 326          True                  NaN           NaN              True
#
#                     Source   Latitude   Longitude
# 0    Sonja Main Data Sheet  49.033403 -119.431551
# 1    Sonja Main Data Sheet  49.034170 -119.433264
# 2    Sonja Main Data Sheet  49.054500 -119.497677
# 3    Sonja Main Data Sheet  49.038404 -119.433498
# 4    Sonja Main Data Sheet  49.037256 -119.477810
# ..                     ...        ...         ...
# 322           TOTA members  49.550050 -119.562867
# 323           TOTA members  50.279820 -119.222820
# 324           TOTA members  49.810994 -119.624089
# 325           TOTA members  49.150165 -119.591051
# 326           TOTA members  49.941786 -119.396122
#
# [327 rows x 23 columns]

# %% [markdown]
# ### 1.2 Load (original) full data

# %%
sheet_id = "1GUqBfjwIlXa_vJDSCqLAfeNwtnRulzZfzRsLA7Y5qIQ"
sheet_name = "Original_data"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
ori_df = pd.read_csv(url)
ori_df['Company ID'] = np.int64(ori_df['Company ID'])
ori_df['Company ID'] = ori_df['Company ID'].apply(lambda x: str(x))
ori_df['Company ID'].replace(to_replace='-9223372036854775808', value=np.nan, inplace=True)

ori_df
# Out:
#       Company ID                      Name of Business/Organization  \
# 0     3339931603                    Planet Bee Honey Farm & Meadery
# 1     3376458342           Best Western Plus Kelowna Hotel & Suites
# 2     3410099603                      Okanagan Lavender & Herb Farm
# 3     3410711087  Blarney Holdings Inc (Globe Cafe & The Blarney...
# 4     3410743392                                     Lakeview Motel
# ...          ...                                                ...
# 3794         NaN  Westbank Indian Band Siya Celebration Cultural...
# 3795         NaN      Westbank Indian Band Sncəwips Heritage Museum
# 3796         NaN                Zipity Doo Dah Adventures (zipline)
# 3797         NaN      Ashnola Campground / Snaʕsnulax̌tn Campground
# 3798         NaN                 Spirit Ridge Vineyard Resort & Spa
#
#                                        Website                 Street  \
# 0                            www.PlanetBee.com  5011 Bella Vista Road
# 1              www.bestwesternkelownahotel.com  2402 Highway 97 North
# 2                     www.okanaganlavender.com        4380 Takla Road
# 3                              globedining.com    5350 Big White Road
# 4                    christinalakeviewmotel.ca         1658 Highway 3
# ...                                        ...                    ...
# 3794    http://www.wfn.ca/siya-celebration.htm                    NaN
# 3795    http://www.wfn.ca/siya-celebration.htm                    NaN
# 3796                      thewildernessway.org                    NaN
# 3797  https://ashnolacampground.wordpress.com/                    NaN
# 3798                        www.spiritridge.ca                    NaN
#
#                 City            Region Postal Code Country     Tourism Region  \
# 0             Vernon  British Columbia     V1H 1A1  Canada  Thompson Okanagan
# 1            Kelowna  British Columbia     V1X 4J1  Canada  Thompson Okanagan
# 2            Kelowna  British Columbia     V1W 3C4  Canada  Thompson Okanagan
# 3          Big White  British Columbia     V1X 4K5  Canada  Thompson Okanagan
# 4     Christina Lake  British Columbia         NaN  Canada  Thompson Okanagan
# ...              ...               ...         ...     ...                ...
# 3794        Westbank  British Columbia     V4T 3A4  Canada  Thompson Okanagan
# 3795        Westbank  British Columbia     V4T 3A4  Canada  Thompson Okanagan
# 3796        Ashcroft  British Columbia     V0K 1A0  Canada  Thompson Okanagan
# 3797        Keremeos  British Columbia     V0X 1N1  Canada  Thompson Okanagan
# 3798         Osoyoos  British Columbia     V0H 1V0  Canada  Thompson Okanagan
#
#      Tourism Sub-Region  ... Accessibility Number of Employees Year Founded  \
# 0        North Okanagan  ...          True                 NaN       1982.0
# 1      Central Okanagan  ...          True               200.0          NaN
# 2      Central Okanagan  ...          True                10.0          NaN
# 3              Boundary  ...         False                25.0          NaN
# 4              Boundary  ...         False                 NaN       2013.0
# ...                 ...  ...           ...                 ...          ...
# 3794                NaN  ...           NaN                 NaN          NaN
# 3795                NaN  ...           NaN                 NaN          NaN
# 3796                NaN  ...           NaN                 NaN          NaN
# 3797                NaN  ...           NaN                 NaN          NaN
# 3798                NaN  ...           NaN                 NaN          NaN
#
#                          Completed Business Type        Business Type  \
# 0                          Activity / Attraction        Accommodation
# 1                                  Accommodation                  NaN
# 2                          Activity / Attraction  Activity/Attraction
# 3                                Food & Beverage      Food & Beverage
# 4                                  Accommodation        Accommodation
# ...                                          ...                  ...
# 3794  Cultural (Museum, Gallery, Festivals, Etc)             Cultural
# 3795  Cultural (Museum, Gallery, Festivals, Etc)             Cultural
# 3796                       Activity / Attraction  Activity/Attraction
# 3797                               Accommodation        Accommodation
# 3798                               Accommodation        Accommodation
#
#       Business Sub-Type Show_on_platform        Source   Latitude   Longitude
# 0                   NaN             True  TOTA members  50.263229 -119.306363
# 1                   NaN             True  TOTA members  49.885027 -119.429031
# 2                   NaN             True  TOTA members  49.823716 -119.448480
# 3                   NaN             True  TOTA members  49.721623 -118.929871
# 4                 Motel             True  TOTA members  49.043105 -118.205474
# ...                 ...              ...           ...        ...         ...
# 3794                NaN             True          ITBC  49.882008 -119.534219
# 3795                NaN             True          ITBC  49.878838 -119.535880
# 3796                NaN             True          ITBC  50.725925 -121.280474
# 3797                NaN             True          ITBC  49.211282 -119.983779
# 3798                NaN             True          ITBC  49.039208 -119.433853
#
# [3799 rows x 28 columns]

# %%
col_orig = ['Company ID', 'Name of Business/Organization', 'Website', 'Street',
       'City', 'Region', 'Postal Code', 'Country', 'Tourism Region',
       'Tourism Sub-Region', 'Business Type Hubspot',
       'Business Sub-Type Hubspot', 'Business Type1', 'Business Type2',
       'Business Tags', 'Indigenous Tourism', 'New_Indig',
       'Biosphere Program Member', 'Accessibility', 'Number of Employees',
       'Year Founded', 'Completed Business Type', 'Business Type',
       'Business Sub-Type', 'Show_on_platform', 'Source', 'Latitude',
       'Longitude']
col_sonja = ['Nr (Sonjas List)', 'Company ID', 'Name of Business/Organization',
       'Website', 'Street', 'City', 'Region', 'Postal Code', 'Country',
       'Tourism Region', 'Tourism Sub-Region', 'Business Type Hubspot',
       'Business Sub-Type Hubspot', 'Tags', 'Indigenous Tourism',
       'Biosphere Program Member', 'Accessibility', 'Number of Employees',
       'Year Founded', 'Show_on_platform', 'Source', 'Latitude', 'Longitude']

[x for x in col_orig if x not in col_sonja]
# Out:
# ['Business Type1',
#  'Business Type2',
#  'Business Tags',
#  'New_Indig',
#  'Completed Business Type',
#  'Business Type',
#  'Business Sub-Type']

# %%
#reduced_df = ori_df[ori_df['Accessibility'] == True][['Company ID', 'New_Indig', 'Completed Business Type','Business Type','Business Sub-Type']].copy()
reduced_df = ori_df[['Company ID', 'Name of Business/Organization' , 'Accessibility' ,'Business Type1',
                     'Business Type2','Business Tags','New_Indig', 'Completed Business Type','Business Type','Business Sub-Type']].copy()
reduced_df = reduced_df.rename(columns={'Accessibility': 'Old_Accessibility'})
reduced_df
# Out:
#       Company ID                      Name of Business/Organization  \
# 0     3339931603                    Planet Bee Honey Farm & Meadery
# 1     3376458342           Best Western Plus Kelowna Hotel & Suites
# 2     3410099603                      Okanagan Lavender & Herb Farm
# 3     3410711087  Blarney Holdings Inc (Globe Cafe & The Blarney...
# 4     3410743392                                     Lakeview Motel
# ...          ...                                                ...
# 3794         NaN  Westbank Indian Band Siya Celebration Cultural...
# 3795         NaN      Westbank Indian Band Sncəwips Heritage Museum
# 3796         NaN                Zipity Doo Dah Adventures (zipline)
# 3797         NaN      Ashnola Campground / Snaʕsnulax̌tn Campground
# 3798         NaN                 Spirit Ridge Vineyard Resort & Spa
#
#      Old_Accessibility       Business Type1  Business Type2  Business Tags  \
# 0                 True  Activity/Attraction             NaN            NaN
# 1                 True        Accommodation             NaN            NaN
# 2                 True  Activity/Attraction             NaN            NaN
# 3                False      Food & Beverage             NaN            NaN
# 4                False        Accommodation             NaN            NaN
# ...                ...                  ...             ...            ...
# 3794               NaN  Activity/Attraction             NaN            NaN
# 3795               NaN  Activity/Attraction             NaN            NaN
# 3796               NaN  Activity/Attraction             NaN            NaN
# 3797               NaN        Accommodation             NaN            NaN
# 3798               NaN        Accommodation             NaN            NaN
#
#      New_Indig                     Completed Business Type  \
# 0     NotFound                       Activity / Attraction
# 1     NotFound                               Accommodation
# 2     NotFound                       Activity / Attraction
# 3     NotFound                             Food & Beverage
# 4         TRUE                               Accommodation
# ...        ...                                         ...
# 3794       NaN  Cultural (Museum, Gallery, Festivals, Etc)
# 3795       NaN  Cultural (Museum, Gallery, Festivals, Etc)
# 3796       NaN                       Activity / Attraction
# 3797       NaN                               Accommodation
# 3798       NaN                               Accommodation
#
#             Business Type Business Sub-Type
# 0           Accommodation               NaN
# 1                     NaN               NaN
# 2     Activity/Attraction               NaN
# 3         Food & Beverage               NaN
# 4           Accommodation             Motel
# ...                   ...               ...
# 3794             Cultural               NaN
# 3795             Cultural               NaN
# 3796  Activity/Attraction               NaN
# 3797        Accommodation               NaN
# 3798        Accommodation               NaN
#
# [3799 rows x 10 columns]

# %%
print(f'Total rows in Sonja\'s dataset: {len(sonja_df)}')
print(f'Total rows in old dataset: {len(ori_df)}')
print(f'Matches between datasets based on COMPANY ID: {len(set(ori_df["Company ID"].dropna()) & set(sonja_df["Company ID"].dropna()))}')
print(f'Matches between datasets based on COMPANY NAME: {len(set(ori_df["Name of Business/Organization"].dropna()) & set(sonja_df["Name of Business/Organization"].dropna()))}')
# Out:
# Total rows in Sonja's dataset: 327
# Total rows in old dataset: 3799
# Matches between datasets based on COMPANY ID: 202
# Matches between datasets based on COMPANY NAME: 227

# %%
df_joined = sonja_df.merge(reduced_df[pd.notnull(reduced_df['Company ID'])], on=['Name of Business/Organization'], how = 'inner')
df_joined
# Out:
#      Nr (Sonjas List) Company ID_x  \
# 0                 1.0   3887918904
# 1                 2.0   4381261090
# 2                 3.0   4381342221
# 3                 4.0   4381289423
# 4                 4.0   4381289423
# ..                ...          ...
# 254               NaN   5066665472
# 255               NaN   4381275569
# 256               NaN   4381282467
# 257               NaN   4381287827
# 258               NaN   4077835569
#
#                      Name of Business/Organization                 Website  \
# 0                            Moon Curser Vineyards          mooncurser.com
# 1                      Adega On 45Th Estate Winery          www.winebc.com
# 2                                  Lastella Winery         www.lastella.ca
# 3                                   Nk'Mip Cellars    www.nkmipcellars.com
# 4                                   Nk'Mip Cellars    www.nkmipcellars.com
# ..                                             ...                     ...
# 254                         Ramada Hotel Penticton                     NaN
# 255  Super 8 By Wyndham Lake Country/Winfield Area   http://www.super8.com
# 256                  The Bx Press Cidery & Orchard  http://thebxpress.com/
# 257                       The Cove Lakeside Resort    www.covelakeside.com
# 258     Ubc Conferences And Accommodation Okanagan  www.ubcconferences.com
#
#                       Street          City            Region Postal Code  \
# 0    3628 British Columbia 3       Osoyoos  British Columbia     V0H 1V6
# 1           7311-45Th Street       Osoyoos  British Columbia     V0H 1V6
# 2            8123 148 Avenue       Osoyoos  British Columbia     V0H 1V0
# 3    1400 Rancher Creek Road       Osoyoos  British Columbia     V0H 1V6
# 4    1400 Rancher Creek Road       Osoyoos  British Columbia     V0H 1V6
# ..                       ...           ...               ...         ...
# 254                      NaN           NaN  British Columbia         NaN
# 255    9564 Highway 97 North  Lake Country  British Columbia     V4V 1T7
# 256    4667 East Vernon Road        Vernon  British Columbia         NaN
# 257       4205 Gellatly Road  West Kelowna  British Columbia     V4T 2K4
# 258  1290 International Mews       Kelowna  British Columbia     V1V 1V8
#
#     Country     Tourism Region  ... Show_on_platform                 Source  \
# 0    Canada  Thompson Okanagan  ...             True  Sonja Main Data Sheet
# 1    Canada  Thompson Okanagan  ...             True  Sonja Main Data Sheet
# 2    Canada  Thompson Okanagan  ...             True  Sonja Main Data Sheet
# 3    Canada  Thompson Okanagan  ...             True  Sonja Main Data Sheet
# 4    Canada  Thompson Okanagan  ...             True  Sonja Main Data Sheet
# ..      ...                ...  ...              ...                    ...
# 254  Canada  Thompson Okanagan  ...             True           TOTA members
# 255  Canada  Thompson Okanagan  ...             True           TOTA members
# 256  Canada  Thompson Okanagan  ...             True           TOTA members
# 257  Canada  Thompson Okanagan  ...             True           TOTA members
# 258  Canada  Thompson Okanagan  ...             True           TOTA members
#
#       Latitude   Longitude  Company ID_y  Old_Accessibility  New_Indig  \
# 0    49.033403 -119.431551    3887918904              False   NotFound
# 1    49.034170 -119.433264    4381261090              False   NotFound
# 2    49.054500 -119.497677    4381342221              False   NotFound
# 3    49.038404 -119.433498    4381289423              False   NotFound
# 4    49.038404 -119.433498    5104154433              False   NotFound
# ..         ...         ...           ...                ...        ...
# 254  49.494342 -119.612784    5066665472              False   NotFound
# 255  50.020787 -119.406957    4381275569              False   NotFound
# 256  50.279820 -119.222820    4381282467              False   NotFound
# 257  49.810994 -119.624089    4381287827              False   NotFound
# 258  49.941786 -119.396122    4077835569              False   NotFound
#
#      Completed Business Type        Business Type  Business Sub-Type
# 0            Food & Beverage      Food & Beverage                NaN
# 1            Food & Beverage      Food & Beverage                NaN
# 2            Food & Beverage      Food & Beverage                NaN
# 3      Activity / Attraction  Activity/Attraction                NaN
# 4            Food & Beverage      Food & Beverage                NaN
# ..                       ...                  ...                ...
# 254            Accommodation        Accommodation              Hotel
# 255            Accommodation        Accommodation                NaN
# 256          Food & Beverage      Food & Beverage                NaN
# 257            Accommodation        Accommodation                NaN
# 258            Accommodation        Accommodation                NaN
#
# [259 rows x 29 columns]

# %%
print(f'Old Accessibility: {reduced_df["Old_Accessibility"].sum()}')
print(f'New Accessibility: {len(sonja_df)}')
print(f'Combined matches: {len(df_joined)}')
print(f'Old Accessibility in New dataset: {df_joined["Old_Accessibility"].sum()}')
# Out:
# Old Accessibility: 64
# New Accessibility: 327
# Combined matches: 259
# Old Accessibility in New dataset: 39

# %%
old = 3799
new = 327
mat = 259

print('Expected total combined cases')

print(old + (new - mat))
# Out:
# Expected total combined cases
# 3867

# %%
df_joined_total = sonja_df.merge(reduced_df[pd.notnull(reduced_df['Name of Business/Organization'])], on=['Name of Business/Organization', 'Company ID'], how = 'outer')
df_joined_total = df_joined_total[pd.notnull(df_joined_total['Accessibility'])]
df_joined_total
# Out:
#      Nr (Sonjas List)  Company ID               Name of Business/Organization  \
# 0                 1.0  3887918904                       Moon Curser Vineyards
# 1                 2.0  4381261090                 Adega On 45Th Estate Winery
# 2                 3.0  4381342221                             Lastella Winery
# 3                 4.0  4381289423                              Nk'Mip Cellars
# 4                 5.0  4373591998      Bordertown Vineyards And Estate Winery
# ..                ...         ...                                         ...
# 322               NaN  5065356135                        Terravista Vineyards
# 323               NaN  4381282467               The Bx Press Cidery & Orchard
# 324               NaN  4381287827                    The Cove Lakeside Resort
# 325               NaN  5105018331                     Tinhorn Creek Vineyards
# 326               NaN  4077835569  Ubc Conferences And Accommodation Okanagan
#
#                     Website                   Street          City  \
# 0            mooncurser.com  3628 British Columbia 3       Osoyoos
# 1            www.winebc.com         7311-45Th Street       Osoyoos
# 2           www.lastella.ca          8123 148 Avenue       Osoyoos
# 3      www.nkmipcellars.com  1400 Rancher Creek Road       Osoyoos
# 4      bordertownwinery.com       9140 - 92Nd Avenue       Osoyoos
# ..                      ...                      ...           ...
# 322                     NaN                      NaN           NaN
# 323  http://thebxpress.com/    4667 East Vernon Road        Vernon
# 324    www.covelakeside.com       4205 Gellatly Road  West Kelowna
# 325             miradoro.ca     537 Tinhorn Creek Rd        Oliver
# 326  www.ubcconferences.com  1290 International Mews       Kelowna
#
#                Region Postal Code Country     Tourism Region  ...   Latitude  \
# 0    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...  49.033403
# 1    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...  49.034170
# 2    British Columbia     V0H 1V0  Canada  Thompson Okanagan  ...  49.054500
# 3    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...  49.038404
# 4    British Columbia     V0H 1V2  Canada  Thompson Okanagan  ...  49.037256
# ..                ...         ...     ...                ...  ...        ...
# 322  British Columbia         NaN  Canada  Thompson Okanagan  ...  49.550050
# 323  British Columbia         NaN  Canada  Thompson Okanagan  ...  50.279820
# 324  British Columbia     V4T 2K4  Canada  Thompson Okanagan  ...  49.810994
# 325  British Columbia     V0H 1T1  Canada  Thompson Okanagan  ...  49.150165
# 326  British Columbia     V1V 1V8  Canada  Thompson Okanagan  ...  49.941786
#
#       Longitude Old_Accessibility       Business Type1 Business Type2  \
# 0   -119.431551             False      Food & Beverage            NaN
# 1   -119.433264             False      Food & Beverage            NaN
# 2   -119.497677             False      Food & Beverage            NaN
# 3   -119.433498             False  Activity/Attraction            NaN
# 4   -119.477810             False      Food & Beverage            NaN
# ..          ...               ...                  ...            ...
# 322 -119.562867             False      Food & Beverage            NaN
# 323 -119.222820             False      Food & Beverage            NaN
# 324 -119.624089             False        Accommodation            NaN
# 325 -119.591051             False      Food & Beverage            NaN
# 326 -119.396122             False        Accommodation            NaN
#
#     Business Tags New_Indig  Completed Business Type        Business Type  \
# 0             NaN  NotFound          Food & Beverage      Food & Beverage
# 1             NaN  NotFound          Food & Beverage      Food & Beverage
# 2             NaN  NotFound          Food & Beverage      Food & Beverage
# 3             NaN  NotFound    Activity / Attraction  Activity/Attraction
# 4             NaN  NotFound          Food & Beverage      Food & Beverage
# ..            ...       ...                      ...                  ...
# 322           NaN  NotFound          Food & Beverage      Food & Beverage
# 323           NaN  NotFound          Food & Beverage      Food & Beverage
# 324           NaN  NotFound            Accommodation        Accommodation
# 325           NaN  NotFound          Food & Beverage      Food & Beverage
# 326           NaN  NotFound            Accommodation        Accommodation
#
#     Business Sub-Type
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 322               NaN
# 323               NaN
# 324               NaN
# 325               NaN
# 326               NaN
#
# [327 rows x 31 columns]

# %%
df_joined_total[df_joined_total['Name of Business/Organization'] == 'Nk\'Mip Cellars']
# Out:
#      Nr (Sonjas List)  Company ID Name of Business/Organization  \
# 3                 4.0  4381289423                Nk'Mip Cellars
# 312               NaN  5104154433                Nk'Mip Cellars
#
#                   Website                   Street     City            Region  \
# 3    www.nkmipcellars.com  1400 Rancher Creek Road  Osoyoos  British Columbia
# 312              mkmip.ca  1400 Rancher Creek Road  Osoyoos  British Columbia
#
#     Postal Code Country     Tourism Region  ...   Latitude   Longitude  \
# 3       V0H 1V6  Canada  Thompson Okanagan  ...  49.038404 -119.433498
# 312     V0H 1V6  Canada  Thompson Okanagan  ...  49.038404 -119.433498
#
#     Old_Accessibility       Business Type1 Business Type2 Business Tags  \
# 3               False  Activity/Attraction            NaN           NaN
# 312             False                  NaN            NaN           NaN
#
#     New_Indig  Completed Business Type        Business Type Business Sub-Type
# 3    NotFound    Activity / Attraction  Activity/Attraction               NaN
# 312  NotFound          Food & Beverage      Food & Beverage               NaN
#
# [2 rows x 31 columns]

# %%
#Create empty DF
clean_df = pd.DataFrame(columns = df_joined_total.columns)

#iterate by row
for i in range(len(df_joined_total)-1):
    
    #check if company name is already in the clean dataframe, add if not.
    if df_joined_total['Name of Business/Organization'][i] not in clean_df['Name of Business/Organization'].values:
        #clean_df.loc[len(clean_df)] = df_joined_total.loc[i]
        clean_df = clean_df.append(df_joined_total.loc[i].copy())
    
    if i in range(0, len(df_joined_total), 30):
        print(f'{round((i/len(df_joined_total))*100, 0)}%')
    
print('100%')
# Out:
# 0.0%
# 9.0%
# 18.0%
# 28.0%
# 37.0%
# 46.0%
# 55.0%
# 64.0%
# 73.0%
# 83.0%
# 92.0%
# 100%

# %%
clean_df
# Out:
#      Nr (Sonjas List)  Company ID  \
# 0                 1.0  3887918904
# 1                 2.0  4381261090
# 2                 3.0  4381342221
# 3                 4.0  4381289423
# 4                 5.0  4373591998
# ..                ...         ...
# 316               NaN  4381261083
# 317               NaN  5066665472
# 320               NaN  4381275569
# 323               NaN  4381282467
# 324               NaN  4381287827
#
#                      Name of Business/Organization  \
# 0                            Moon Curser Vineyards
# 1                      Adega On 45Th Estate Winery
# 2                                  Lastella Winery
# 3                                   Nk'Mip Cellars
# 4           Bordertown Vineyards And Estate Winery
# ..                                             ...
# 316       Ramada Hotel & Conference Centre Kelowna
# 317                         Ramada Hotel Penticton
# 320  Super 8 By Wyndham Lake Country/Winfield Area
# 323                  The Bx Press Cidery & Orchard
# 324                       The Cove Lakeside Resort
#
#                              Website                   Street          City  \
# 0                     mooncurser.com  3628 British Columbia 3       Osoyoos
# 1                     www.winebc.com         7311-45Th Street       Osoyoos
# 2                    www.lastella.ca          8123 148 Avenue       Osoyoos
# 3               www.nkmipcellars.com  1400 Rancher Creek Road       Osoyoos
# 4               bordertownwinery.com       9140 - 92Nd Avenue       Osoyoos
# ..                               ...                      ...           ...
# 316  www.ramadalodgehotelkelowna.com          2170 Harvey Ave       Kelowna
# 317                              NaN                      NaN           NaN
# 320            http://www.super8.com    9564 Highway 97 North  Lake Country
# 323           http://thebxpress.com/    4667 East Vernon Road        Vernon
# 324             www.covelakeside.com       4205 Gellatly Road  West Kelowna
#
#                Region Postal Code Country     Tourism Region  ...   Latitude  \
# 0    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...  49.033403
# 1    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...  49.034170
# 2    British Columbia     V0H 1V0  Canada  Thompson Okanagan  ...  49.054500
# 3    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...  49.038404
# 4    British Columbia     V0H 1V2  Canada  Thompson Okanagan  ...  49.037256
# ..                ...         ...     ...                ...  ...        ...
# 316  British Columbia     V1Y 6G8  Canada  Thompson Okanagan  ...  49.882281
# 317  British Columbia         NaN  Canada  Thompson Okanagan  ...  49.494342
# 320  British Columbia     V4V 1T7  Canada  Thompson Okanagan  ...  50.020787
# 323  British Columbia         NaN  Canada  Thompson Okanagan  ...  50.279820
# 324  British Columbia     V4T 2K4  Canada  Thompson Okanagan  ...  49.810994
#
#       Longitude Old_Accessibility       Business Type1 Business Type2  \
# 0   -119.431551             False      Food & Beverage            NaN
# 1   -119.433264             False      Food & Beverage            NaN
# 2   -119.497677             False      Food & Beverage            NaN
# 3   -119.433498             False  Activity/Attraction            NaN
# 4   -119.477810             False      Food & Beverage            NaN
# ..          ...               ...                  ...            ...
# 316 -119.438052             False        Accommodation            NaN
# 317 -119.612784             False        Accommodation            NaN
# 320 -119.406957             False        Accommodation            NaN
# 323 -119.222820             False      Food & Beverage            NaN
# 324 -119.624089             False        Accommodation            NaN
#
#     Business Tags New_Indig  Completed Business Type        Business Type  \
# 0             NaN  NotFound          Food & Beverage      Food & Beverage
# 1             NaN  NotFound          Food & Beverage      Food & Beverage
# 2             NaN  NotFound          Food & Beverage      Food & Beverage
# 3             NaN  NotFound    Activity / Attraction  Activity/Attraction
# 4             NaN  NotFound          Food & Beverage      Food & Beverage
# ..            ...       ...                      ...                  ...
# 316           NaN  NotFound            Accommodation        Accommodation
# 317           NaN  NotFound            Accommodation        Accommodation
# 320           NaN  NotFound            Accommodation        Accommodation
# 323           NaN  NotFound          Food & Beverage      Food & Beverage
# 324           NaN  NotFound            Accommodation        Accommodation
#
#     Business Sub-Type
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 316               NaN
# 317             Hotel
# 320               NaN
# 323               NaN
# 324               NaN
#
# [313 rows x 31 columns]

# %%
final_cols = ['Nr (Sonjas List)','Company ID', 'Name of Business/Organization', 'Website', 'Street',
       'City', 'Region', 'Postal Code', 'Country', 'Tourism Region',
       'Tourism Sub-Region', 'Business Type Hubspot',
       'Business Sub-Type Hubspot', 'Business Type1', 'Business Type2',
       'Business Tags', 'Indigenous Tourism', 'New_Indig',
       'Biosphere Program Member', 'Accessibility', 'Number of Employees',
       'Year Founded', 'Completed Business Type', 'Business Type',
       'Business Sub-Type', 'Show_on_platform', 'Source', 'Latitude',
       'Longitude']

# %%
clean_df_select = clean_df[final_cols]
clean_df_select
# Out:
#      Nr (Sonjas List)  Company ID  \
# 0                 1.0  3887918904
# 1                 2.0  4381261090
# 2                 3.0  4381342221
# 3                 4.0  4381289423
# 4                 5.0  4373591998
# ..                ...         ...
# 316               NaN  4381261083
# 317               NaN  5066665472
# 320               NaN  4381275569
# 323               NaN  4381282467
# 324               NaN  4381287827
#
#                      Name of Business/Organization  \
# 0                            Moon Curser Vineyards
# 1                      Adega On 45Th Estate Winery
# 2                                  Lastella Winery
# 3                                   Nk'Mip Cellars
# 4           Bordertown Vineyards And Estate Winery
# ..                                             ...
# 316       Ramada Hotel & Conference Centre Kelowna
# 317                         Ramada Hotel Penticton
# 320  Super 8 By Wyndham Lake Country/Winfield Area
# 323                  The Bx Press Cidery & Orchard
# 324                       The Cove Lakeside Resort
#
#                              Website                   Street          City  \
# 0                     mooncurser.com  3628 British Columbia 3       Osoyoos
# 1                     www.winebc.com         7311-45Th Street       Osoyoos
# 2                    www.lastella.ca          8123 148 Avenue       Osoyoos
# 3               www.nkmipcellars.com  1400 Rancher Creek Road       Osoyoos
# 4               bordertownwinery.com       9140 - 92Nd Avenue       Osoyoos
# ..                               ...                      ...           ...
# 316  www.ramadalodgehotelkelowna.com          2170 Harvey Ave       Kelowna
# 317                              NaN                      NaN           NaN
# 320            http://www.super8.com    9564 Highway 97 North  Lake Country
# 323           http://thebxpress.com/    4667 East Vernon Road        Vernon
# 324             www.covelakeside.com       4205 Gellatly Road  West Kelowna
#
#                Region Postal Code Country     Tourism Region  ...  \
# 0    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 1    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 2    British Columbia     V0H 1V0  Canada  Thompson Okanagan  ...
# 3    British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 4    British Columbia     V0H 1V2  Canada  Thompson Okanagan  ...
# ..                ...         ...     ...                ...  ...
# 316  British Columbia     V1Y 6G8  Canada  Thompson Okanagan  ...
# 317  British Columbia         NaN  Canada  Thompson Okanagan  ...
# 320  British Columbia     V4V 1T7  Canada  Thompson Okanagan  ...
# 323  British Columbia         NaN  Canada  Thompson Okanagan  ...
# 324  British Columbia     V4T 2K4  Canada  Thompson Okanagan  ...
#
#     Accessibility Number of Employees Year Founded Completed Business Type  \
# 0            True                10.0       2003.0         Food & Beverage
# 1            True                 NaN       2011.0         Food & Beverage
# 2            True                50.0       2005.0         Food & Beverage
# 3            True                 NaN       2003.0   Activity / Attraction
# 4            True                 NaN          NaN         Food & Beverage
# ..            ...                 ...          ...                     ...
# 316          True                 NaN       1991.0           Accommodation
# 317          True                 NaN          NaN           Accommodation
# 320          True             10000.0       1981.0           Accommodation
# 323          True                 NaN          NaN         Food & Beverage
# 324          True                50.0       2006.0           Accommodation
#
#            Business Type  Business Sub-Type Show_on_platform  \
# 0        Food & Beverage                NaN             True
# 1        Food & Beverage                NaN             True
# 2        Food & Beverage                NaN             True
# 3    Activity/Attraction                NaN             True
# 4        Food & Beverage                NaN             True
# ..                   ...                ...              ...
# 316        Accommodation                NaN             True
# 317        Accommodation              Hotel             True
# 320        Accommodation                NaN             True
# 323      Food & Beverage                NaN             True
# 324        Accommodation                NaN             True
#
#                     Source   Latitude   Longitude
# 0    Sonja Main Data Sheet  49.033403 -119.431551
# 1    Sonja Main Data Sheet  49.034170 -119.433264
# 2    Sonja Main Data Sheet  49.054500 -119.497677
# 3    Sonja Main Data Sheet  49.038404 -119.433498
# 4    Sonja Main Data Sheet  49.037256 -119.477810
# ..                     ...        ...         ...
# 316           TOTA members  49.882281 -119.438052
# 317           TOTA members  49.494342 -119.612784
# 320           TOTA members  50.020787 -119.406957
# 323           TOTA members  50.279820 -119.222820
# 324           TOTA members  49.810994 -119.624089
#
# [313 rows x 29 columns]

# %%
complementary_df = ori_df[~ori_df['Name of Business/Organization'].isin(clean_df['Name of Business/Organization'])].copy()
complementary_df['Nr (Sonjas List)'] = np.nan
complementary_df = complementary_df[final_cols].reset_index()
complementary_df.drop(columns = ['index'], inplace = True)
complementary_df
# Out:
#       Nr (Sonjas List)  Company ID  \
# 0                  NaN  3410099603
# 1                  NaN  3410711087
# 2                  NaN  3410743392
# 3                  NaN  3411328350
# 4                  NaN  3415411981
# ...                ...         ...
# 3556               NaN         NaN
# 3557               NaN         NaN
# 3558               NaN         NaN
# 3559               NaN         NaN
# 3560               NaN         NaN
#
#                           Name of Business/Organization  \
# 0                         Okanagan Lavender & Herb Farm
# 1     Blarney Holdings Inc (Globe Cafe & The Blarney...
# 2                                        Lakeview Motel
# 3                  Smitty's Family Restaurant - Kelowna
# 4                               Double E Sportsman Camp
# ...                                                 ...
# 3556  Westbank Indian Band Siya Celebration Cultural...
# 3557      Westbank Indian Band Sncəwips Heritage Museum
# 3558                Zipity Doo Dah Adventures (zipline)
# 3559      Ashnola Campground / Snaʕsnulax̌tn Campground
# 3560                 Spirit Ridge Vineyard Resort & Spa
#
#                                        Website                      Street  \
# 0                     www.okanaganlavender.com             4380 Takla Road
# 1                              globedining.com         5350 Big White Road
# 2                    christinalakeviewmotel.ca              1658 Highway 3
# 3                                   smittys.ca          2170 Harvery Aenue
# 4                    doubleesportsmanscamp.com  5575 Christian Valley Road
# ...                                        ...                         ...
# 3556    http://www.wfn.ca/siya-celebration.htm                         NaN
# 3557    http://www.wfn.ca/siya-celebration.htm                         NaN
# 3558                      thewildernessway.org                         NaN
# 3559  https://ashnolacampground.wordpress.com/                         NaN
# 3560                        www.spiritridge.ca                         NaN
#
#                 City            Region Postal Code Country     Tourism Region  \
# 0            Kelowna  British Columbia     V1W 3C4  Canada  Thompson Okanagan
# 1          Big White  British Columbia     V1X 4K5  Canada  Thompson Okanagan
# 2     Christina Lake  British Columbia         NaN  Canada  Thompson Okanagan
# 3            Kelowna  British Columbia     V1Y 6G8  Canada  Thompson Okanagan
# 4         Westbridge  British Columbia     V0H 1Y0  Canada  Thompson Okanagan
# ...              ...               ...         ...     ...                ...
# 3556        Westbank  British Columbia     V4T 3A4  Canada  Thompson Okanagan
# 3557        Westbank  British Columbia     V4T 3A4  Canada  Thompson Okanagan
# 3558        Ashcroft  British Columbia     V0K 1A0  Canada  Thompson Okanagan
# 3559        Keremeos  British Columbia     V0X 1N1  Canada  Thompson Okanagan
# 3560         Osoyoos  British Columbia     V0H 1V0  Canada  Thompson Okanagan
#
#       ... Accessibility Number of Employees Year Founded  \
# 0     ...          True                10.0          NaN
# 1     ...         False                25.0          NaN
# 2     ...         False                 NaN       2013.0
# 3     ...         False              1000.0       1960.0
# 4     ...         False                 NaN          NaN
# ...   ...           ...                 ...          ...
# 3556  ...           NaN                 NaN          NaN
# 3557  ...           NaN                 NaN          NaN
# 3558  ...           NaN                 NaN          NaN
# 3559  ...           NaN                 NaN          NaN
# 3560  ...           NaN                 NaN          NaN
#
#                          Completed Business Type        Business Type  \
# 0                          Activity / Attraction  Activity/Attraction
# 1                                Food & Beverage      Food & Beverage
# 2                                  Accommodation        Accommodation
# 3                                Food & Beverage      Food & Beverage
# 4                                  Accommodation        Accommodation
# ...                                          ...                  ...
# 3556  Cultural (Museum, Gallery, Festivals, Etc)             Cultural
# 3557  Cultural (Museum, Gallery, Festivals, Etc)             Cultural
# 3558                       Activity / Attraction  Activity/Attraction
# 3559                               Accommodation        Accommodation
# 3560                               Accommodation        Accommodation
#
#       Business Sub-Type  Show_on_platform        Source   Latitude   Longitude
# 0                   NaN              True  TOTA members  49.823716 -119.448480
# 1                   NaN              True  TOTA members  49.721623 -118.929871
# 2                 Motel              True  TOTA members  49.043105 -118.205474
# 3                   NaN              True  TOTA members  49.882281 -119.438052
# 4                   NaN              True  TOTA members  49.321564 -118.880127
# ...                 ...               ...           ...        ...         ...
# 3556                NaN              True          ITBC  49.882008 -119.534219
# 3557                NaN              True          ITBC  49.878838 -119.535880
# 3558                NaN              True          ITBC  50.725925 -121.280474
# 3559                NaN              True          ITBC  49.211282 -119.983779
# 3560                NaN              True          ITBC  49.039208 -119.433853
#
# [3561 rows x 29 columns]

# %%
for i in range(len(complementary_df)-1):
    
    #check if company name is already in the clean dataframe, add if not.
    if complementary_df['Name of Business/Organization'][i] not in clean_df_select['Name of Business/Organization'].values:
        #clean_df.loc[len(clean_df)] = df_joined_total.loc[i]
        clean_df_select = clean_df_select.append(complementary_df.loc[i].copy())
    
    if i in range(0, len(complementary_df), 200):
        print(f'{round((i/len(complementary_df))*100, 0)}%')
    
print('100%')
# Out:
# 0.0%
# 6.0%
# 11.0%
# 17.0%
# 22.0%
# 28.0%
# 34.0%
# 39.0%
# 45.0%
# 51.0%
# 56.0%
# 62.0%
# 67.0%
# 73.0%
# 79.0%
# 84.0%
# 90.0%
# 95.0%
# 100%

# %%
clean_df_select
# Out:
#       Nr (Sonjas List)  Company ID  \
# 0                  1.0  3887918904
# 1                  2.0  4381261090
# 2                  3.0  4381342221
# 3                  4.0  4381289423
# 4                  5.0  4373591998
# ...                ...         ...
# 3555               NaN         NaN
# 3556               NaN         NaN
# 3557               NaN         NaN
# 3558               NaN         NaN
# 3559               NaN         NaN
#
#                           Name of Business/Organization  \
# 0                                 Moon Curser Vineyards
# 1                           Adega On 45Th Estate Winery
# 2                                       Lastella Winery
# 3                                        Nk'Mip Cellars
# 4                Bordertown Vineyards And Estate Winery
# ...                                                 ...
# 3555    Westbank Indian Band - Sncewips Heritage Museum
# 3556  Westbank Indian Band Siya Celebration Cultural...
# 3557      Westbank Indian Band Sncəwips Heritage Museum
# 3558                Zipity Doo Dah Adventures (zipline)
# 3559      Ashnola Campground / Snaʕsnulax̌tn Campground
#
#                                        Website                   Street  \
# 0                               mooncurser.com  3628 British Columbia 3
# 1                               www.winebc.com         7311-45Th Street
# 2                              www.lastella.ca          8123 148 Avenue
# 3                         www.nkmipcellars.com  1400 Rancher Creek Road
# 4                         bordertownwinery.com       9140 - 92Nd Avenue
# ...                                        ...                      ...
# 3555                 https://www.sncewips.com/                      NaN
# 3556    http://www.wfn.ca/siya-celebration.htm                      NaN
# 3557    http://www.wfn.ca/siya-celebration.htm                      NaN
# 3558                      thewildernessway.org                      NaN
# 3559  https://ashnolacampground.wordpress.com/                      NaN
#
#           City            Region Postal Code Country     Tourism Region  ...  \
# 0      Osoyoos  British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 1      Osoyoos  British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 2      Osoyoos  British Columbia     V0H 1V0  Canada  Thompson Okanagan  ...
# 3      Osoyoos  British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 4      Osoyoos  British Columbia     V0H 1V2  Canada  Thompson Okanagan  ...
# ...        ...               ...         ...     ...                ...  ...
# 3555       NaN  British Columbia         NaN  Canada  Thompson Okanagan  ...
# 3556  Westbank  British Columbia     V4T 3A4  Canada  Thompson Okanagan  ...
# 3557  Westbank  British Columbia     V4T 3A4  Canada  Thompson Okanagan  ...
# 3558  Ashcroft  British Columbia     V0K 1A0  Canada  Thompson Okanagan  ...
# 3559  Keremeos  British Columbia     V0X 1N1  Canada  Thompson Okanagan  ...
#
#      Accessibility Number of Employees Year Founded  \
# 0             True                10.0       2003.0
# 1             True                 NaN       2011.0
# 2             True                50.0       2005.0
# 3             True                 NaN       2003.0
# 4             True                 NaN          NaN
# ...            ...                 ...          ...
# 3555           NaN                 NaN          NaN
# 3556           NaN                 NaN          NaN
# 3557           NaN                 NaN          NaN
# 3558           NaN                 NaN          NaN
# 3559           NaN                 NaN          NaN
#
#                          Completed Business Type        Business Type  \
# 0                                Food & Beverage      Food & Beverage
# 1                                Food & Beverage      Food & Beverage
# 2                                Food & Beverage      Food & Beverage
# 3                          Activity / Attraction  Activity/Attraction
# 4                                Food & Beverage      Food & Beverage
# ...                                          ...                  ...
# 3555  Cultural (Museum, Gallery, Festivals, Etc)             Cultural
# 3556  Cultural (Museum, Gallery, Festivals, Etc)             Cultural
# 3557  Cultural (Museum, Gallery, Festivals, Etc)             Cultural
# 3558                       Activity / Attraction  Activity/Attraction
# 3559                               Accommodation        Accommodation
#
#       Business Sub-Type Show_on_platform                 Source   Latitude  \
# 0                   NaN             True  Sonja Main Data Sheet  49.033403
# 1                   NaN             True  Sonja Main Data Sheet  49.034170
# 2                   NaN             True  Sonja Main Data Sheet  49.054500
# 3                   NaN             True  Sonja Main Data Sheet  49.038404
# 4                   NaN             True  Sonja Main Data Sheet  49.037256
# ...                 ...              ...                    ...        ...
# 3555                NaN             True                   ITBC  49.878838
# 3556                NaN             True                   ITBC  49.882008
# 3557                NaN             True                   ITBC  49.878838
# 3558                NaN             True                   ITBC  50.725925
# 3559                NaN             True                   ITBC  49.211282
#
#        Longitude
# 0    -119.431551
# 1    -119.433264
# 2    -119.497677
# 3    -119.433498
# 4    -119.477810
# ...          ...
# 3555 -119.535880
# 3556 -119.534219
# 3557 -119.535880
# 3558 -121.280474
# 3559 -119.983779
#
# [3751 rows x 29 columns]

# %%
clean_df_select['Accessibility'].sum()
# Out:
# 344

# %%
clean_df_select = clean_df_select[final_cols].reset_index()
clean_df_select.drop(columns = ['index'], inplace = True)
clean_df_select
# Out:
#       Nr (Sonjas List)  Company ID  \
# 0                  1.0  3887918904
# 1                  2.0  4381261090
# 2                  3.0  4381342221
# 3                  4.0  4381289423
# 4                  5.0  4373591998
# ...                ...         ...
# 3746               NaN         NaN
# 3747               NaN         NaN
# 3748               NaN         NaN
# 3749               NaN         NaN
# 3750               NaN         NaN
#
#                           Name of Business/Organization  \
# 0                                 Moon Curser Vineyards
# 1                           Adega On 45Th Estate Winery
# 2                                       Lastella Winery
# 3                                        Nk'Mip Cellars
# 4                Bordertown Vineyards And Estate Winery
# ...                                                 ...
# 3746    Westbank Indian Band - Sncewips Heritage Museum
# 3747  Westbank Indian Band Siya Celebration Cultural...
# 3748      Westbank Indian Band Sncəwips Heritage Museum
# 3749                Zipity Doo Dah Adventures (zipline)
# 3750      Ashnola Campground / Snaʕsnulax̌tn Campground
#
#                                        Website                   Street  \
# 0                               mooncurser.com  3628 British Columbia 3
# 1                               www.winebc.com         7311-45Th Street
# 2                              www.lastella.ca          8123 148 Avenue
# 3                         www.nkmipcellars.com  1400 Rancher Creek Road
# 4                         bordertownwinery.com       9140 - 92Nd Avenue
# ...                                        ...                      ...
# 3746                 https://www.sncewips.com/                      NaN
# 3747    http://www.wfn.ca/siya-celebration.htm                      NaN
# 3748    http://www.wfn.ca/siya-celebration.htm                      NaN
# 3749                      thewildernessway.org                      NaN
# 3750  https://ashnolacampground.wordpress.com/                      NaN
#
#           City            Region Postal Code Country     Tourism Region  ...  \
# 0      Osoyoos  British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 1      Osoyoos  British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 2      Osoyoos  British Columbia     V0H 1V0  Canada  Thompson Okanagan  ...
# 3      Osoyoos  British Columbia     V0H 1V6  Canada  Thompson Okanagan  ...
# 4      Osoyoos  British Columbia     V0H 1V2  Canada  Thompson Okanagan  ...
# ...        ...               ...         ...     ...                ...  ...
# 3746       NaN  British Columbia         NaN  Canada  Thompson Okanagan  ...
# 3747  Westbank  British Columbia     V4T 3A4  Canada  Thompson Okanagan  ...
# 3748  Westbank  British Columbia     V4T 3A4  Canada  Thompson Okanagan  ...
# 3749  Ashcroft  British Columbia     V0K 1A0  Canada  Thompson Okanagan  ...
# 3750  Keremeos  British Columbia     V0X 1N1  Canada  Thompson Okanagan  ...
#
#      Accessibility Number of Employees Year Founded  \
# 0             True                10.0       2003.0
# 1             True                 NaN       2011.0
# 2             True                50.0       2005.0
# 3             True                 NaN       2003.0
# 4             True                 NaN          NaN
# ...            ...                 ...          ...
# 3746           NaN                 NaN          NaN
# 3747           NaN                 NaN          NaN
# 3748           NaN                 NaN          NaN
# 3749           NaN                 NaN          NaN
# 3750           NaN                 NaN          NaN
#
#                          Completed Business Type        Business Type  \
# 0                                Food & Beverage      Food & Beverage
# 1                                Food & Beverage      Food & Beverage
# 2                                Food & Beverage      Food & Beverage
# 3                          Activity / Attraction  Activity/Attraction
# 4                                Food & Beverage      Food & Beverage
# ...                                          ...                  ...
# 3746  Cultural (Museum, Gallery, Festivals, Etc)             Cultural
# 3747  Cultural (Museum, Gallery, Festivals, Etc)             Cultural
# 3748  Cultural (Museum, Gallery, Festivals, Etc)             Cultural
# 3749                       Activity / Attraction  Activity/Attraction
# 3750                               Accommodation        Accommodation
#
#       Business Sub-Type Show_on_platform                 Source   Latitude  \
# 0                   NaN             True  Sonja Main Data Sheet  49.033403
# 1                   NaN             True  Sonja Main Data Sheet  49.034170
# 2                   NaN             True  Sonja Main Data Sheet  49.054500
# 3                   NaN             True  Sonja Main Data Sheet  49.038404
# 4                   NaN             True  Sonja Main Data Sheet  49.037256
# ...                 ...              ...                    ...        ...
# 3746                NaN             True                   ITBC  49.878838
# 3747                NaN             True                   ITBC  49.882008
# 3748                NaN             True                   ITBC  49.878838
# 3749                NaN             True                   ITBC  50.725925
# 3750                NaN             True                   ITBC  49.211282
#
#        Longitude
# 0    -119.431551
# 1    -119.433264
# 2    -119.497677
# 3    -119.433498
# 4    -119.477810
# ...          ...
# 3746 -119.535880
# 3747 -119.534219
# 3748 -119.535880
# 3749 -121.280474
# 3750 -119.983779
#
# [3751 rows x 29 columns]

# %%
clean_df_select.to_csv('../data/business_TOTA_merged.csv', index = False)
