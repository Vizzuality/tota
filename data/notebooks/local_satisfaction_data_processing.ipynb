# %% [markdown]
# # Local Satisfaction data preparation
# This notebook shows the process of getting data from **wide format** (for each observation, as many columns as questions) to **long format** (a column for the question, and a column for the answer, for all the data)

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## 1) Load data
# Load the original data from the google sheet

# %%
sheet_id = '1iXFCOE7iAhpajY9v2GjtZM21GDDTjWFRzeO8Q_InP7E'
sheet_name = 'simplified_data'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

original_data = pd.read_csv(url)
original_data['id'] = original_data.index
original_data
# Out:
#       Satisfaction with life   Sense of belonging in community   \
# 0                          80                              75.0
# 1                          60                               0.0
# 2                          80                             100.0
# 3                          70                              50.0
# 4                          70                             100.0
# ...                       ...                               ...
# 1360                       90                              75.0
# 1361                       20                               NaN
# 1362                       70                              75.0
# 1363                       80                               0.0
# 1364                       50                              50.0
#
#       Satisfaction with tourism  Satisfaction with tourism .1  \
# 0                           70.0                    Increase
# 1                            NaN                          NaN
# 2                            NaN                    Increase
# 3                            NaN                          NaN
# 4                           90.0                    Increase
# ...                          ...                          ...
# 1360                        70.0                    Increase
# 1361                         NaN                          NaN
# 1362                         NaN               Stay the same
# 1363                        10.0    I do not have an opinion.
# 1364                       100.0    I do not have an opinion.
#
#                                                Tourism   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Nearby BC communities         | All of BC | Ot...
# ...                                                 ...
# 1360  All of BC | Other Canadian provinces | United ...
# 1361                                                NaN
# 1362  Nearby BC communities         | All of BC | Ot...
# 1363  Nearby BC communities         | All of BC | Ot...
# 1364  Nearby BC communities         | All of BC | Ot...
#
#                                      Jobs with tourism   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     British Columbia Visitors         | Canadian V...
# ...                                                 ...
# 1360  Canadian Visitors | United States of America  ...
# 1361                                                NaN
# 1362  British Columbia Visitors         | Canadian V...
# 1363                  British Columbia Visitors
# 1364  British Columbia Visitors         | Canadian V...
#
#       Entrepreneurship with tourism   Local culture from tourism   \
# 0                              100.0                        100.0
# 1                                NaN                          NaN
# 2                              100.0                        100.0
# 3                                NaN                          NaN
# 4                               75.0                         75.0
# ...                              ...                          ...
# 1360                            75.0                         75.0
# 1361                             NaN                          NaN
# 1362                            75.0                         50.0
# 1363                            25.0                         25.0
# 1364                            75.0                         75.0
#
#       Production of local productions with tourism   \
# 0                                             100.0
# 1                                               NaN
# 2                                             100.0
# 3                                               NaN
# 4                                              75.0
# ...                                             ...
# 1360                                           75.0
# 1361                                            NaN
# 1362                                           50.0
# 1363                                           25.0
# 1364                                           75.0
#
#       Views on policies on tourism    \
# 0                              100.0
# 1                                NaN
# 2                              100.0
# 3                                NaN
# 4                               75.0
# ...                              ...
# 1360                            75.0
# 1361                             NaN
# 1362                            75.0
# 1363                            25.0
# 1364                            75.0
#
#       Satisfaction with the quality of basic educational services   \
# 0                                                 100.0
# 1                                                   NaN
# 2                                                 100.0
# 3                                                   NaN
# 4                                                  75.0
# ...                                                 ...
# 1360                                                0.0
# 1361                                                NaN
# 1362                                               50.0
# 1363                                               50.0
# 1364                                               50.0
#
#      Satisfaction with the quality of basic healh services   \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   Yes
# ...                                                 ...
# 1360                                                Yes
# 1361                                                NaN
# 1362                                                Yes
# 1363                                                 No
# 1364                                                Yes
#
#       Satisfaction with access to recreation  \
# 0                                       75.0
# 1                                       75.0
# 2                                      100.0
# 3                                       50.0
# 4                                       75.0
# ...                                      ...
# 1360                                    25.0
# 1361                                     NaN
# 1362                                    75.0
# 1363                                    25.0
# 1364                                    75.0
#
#       Satisfaction with access to cultural activities  \
# 0                                               100.0
# 1                                                50.0
# 2                                                 0.0
# 3                                                75.0
# 4                                                75.0
# ...                                               ...
# 1360                                             25.0
# 1361                                              NaN
# 1362                                             75.0
# 1363                                             25.0
# 1364                                             75.0
#
#       Satisfaction with safety  Sense of a healthy environment     id
# 0                         50.0                             75.0     0
# 1                        100.0                             75.0     1
# 2                        100.0                             75.0     2
# 3                         75.0                             50.0     3
# 4                         50.0                             50.0     4
# ...                        ...                              ...   ...
# 1360                       NaN                             75.0  1360
# 1361                       NaN                              NaN  1361
# 1362                      75.0                             75.0  1362
# 1363                       0.0                             50.0  1363
# 1364                     100.0                             50.0  1364
#
# [1365 rows x 17 columns]

# %% [markdown]
# ## Transform to long format

# %%
df_long = pd.melt(original_data, id_vars=['id'], var_name='Topic', value_name='Answer')
df_long
# Out:
#          id                            Topic Answer
# 0         0          Satisfaction with life      80
# 1         1          Satisfaction with life      60
# 2         2          Satisfaction with life      80
# 3         3          Satisfaction with life      70
# 4         4          Satisfaction with life      70
# ...     ...                              ...    ...
# 21835  1360  Sense of a healthy environment    75.0
# 21836  1361  Sense of a healthy environment     NaN
# 21837  1362  Sense of a healthy environment    75.0
# 21838  1363  Sense of a healthy environment    50.0
# 21839  1364  Sense of a healthy environment    50.0
#
# [21840 rows x 3 columns]

# %% [markdown]
# ## 2) Modify / group data
# The following categories (questions/topics) need cleaning, separating multiple choice answers and/or removing invalid answers
# - Jobs with tourism
# - Tourism
# - Satisfaction with tourism .1
#
# The process will be to get the subset of data, modify it, and then remove and replace on the initial data table.

# %% [markdown]
# ### Jobs with tourism
# **Question:**
# _If you saw an advertisement promoting your region as a place for tourists to visit would you agree it was appropriate for the following locations?  (Check all that apply)_

# %%
jobs = df_long.loc[df_long['Topic'] == 'Jobs with tourism '].copy()
jobs
# Out:
#         id               Topic  \
# 6825     0  Jobs with tourism
# 6826     1  Jobs with tourism
# 6827     2  Jobs with tourism
# 6828     3  Jobs with tourism
# 6829     4  Jobs with tourism
# ...    ...                 ...
# 8185  1360  Jobs with tourism
# 8186  1361  Jobs with tourism
# 8187  1362  Jobs with tourism
# 8188  1363  Jobs with tourism
# 8189  1364  Jobs with tourism
#
#                                                  Answer
# 6825                                                NaN
# 6826                                                NaN
# 6827                                                NaN
# 6828                                                NaN
# 6829  British Columbia Visitors         | Canadian V...
# ...                                                 ...
# 8185  Canadian Visitors | United States of America  ...
# 8186                                                NaN
# 8187  British Columbia Visitors         | Canadian V...
# 8188                  British Columbia Visitors
# 8189  British Columbia Visitors         | Canadian V...
#
# [1365 rows x 3 columns]

# %%
jobs.Answer.unique()
# Out:
# array([nan,
#        'British Columbia Visitors         | Canadian Visitors | United States of America        | Other countries',
#        'British Columbia Visitors        ',
#        'British Columbia Visitors         | Canadian Visitors | United States of America       ',
#        'Canadian Visitors',
#        'British Columbia Visitors         | Canadian Visitors | Other countries',
#        'Other countries',
#        'British Columbia Visitors         | Canadian Visitors',
#        'United States of America       ',
#        'British Columbia Visitors         | United States of America        | Other countries',
#        'Canadian Visitors | United States of America       ',
#        'Canadian Visitors | Other countries',
#        'Canadian Visitors | United States of America        | Other countries',
#        'British Columbia Visitors         | Other countries',
#        'British Columbia Visitors         | United States of America       ',
#        'United States of America        | Other countries'], dtype=object)

# %% [markdown]
# Get choices in different columns and then in long format

# %%
jobs_exp = jobs['Answer'].dropna().str.split('|', expand=True)
jobs_exp['id'] = jobs_exp.index
jobs_exp
# Out:
#                                        0                                  1  \
# 6829  British Columbia Visitors                          Canadian Visitors
# 6830  British Columbia Visitors                          Canadian Visitors
# 6831  British Columbia Visitors                          Canadian Visitors
# 6832  British Columbia Visitors                          Canadian Visitors
# 6833  British Columbia Visitors                          Canadian Visitors
# ...                                  ...                                ...
# 8184  British Columbia Visitors                          Canadian Visitors
# 8185                  Canadian Visitors    United States of America
# 8187  British Columbia Visitors                           Canadian Visitors
# 8188   British Columbia Visitors                                       None
# 8189  British Columbia Visitors                          Canadian Visitors
#
#                                       2                 3    id
# 6829   United States of America           Other countries  6829
# 6830   United States of America           Other countries  6830
# 6831   United States of America           Other countries  6831
# 6832   United States of America           Other countries  6832
# 6833   United States of America           Other countries  6833
# ...                                 ...               ...   ...
# 8184   United States of America           Other countries  8184
# 8185                    Other countries              None  8185
# 8187                               None              None  8187
# 8188                               None              None  8188
# 8189    United States of America                     None  8189
#
# [1027 rows x 5 columns]

# %%
jobs_long = pd.melt(jobs_exp, id_vars=['id'], var_name='Topic', value_name='Answer')
jobs_long['Topic'] = 'Jobs with tourism'
jobs_long = jobs_long[~jobs_long['Answer'].isna()]
jobs_long['Answer'] = jobs_long['Answer'].str.strip()
jobs_long
# Out:
#         id              Topic                     Answer
# 0     6829  Jobs with tourism  British Columbia Visitors
# 1     6830  Jobs with tourism  British Columbia Visitors
# 2     6831  Jobs with tourism  British Columbia Visitors
# 3     6832  Jobs with tourism  British Columbia Visitors
# 4     6833  Jobs with tourism  British Columbia Visitors
# ...    ...                ...                        ...
# 4097  8173  Jobs with tourism            Other countries
# 4100  8178  Jobs with tourism            Other countries
# 4101  8180  Jobs with tourism            Other countries
# 4102  8181  Jobs with tourism            Other countries
# 4103  8184  Jobs with tourism            Other countries
#
# [3196 rows x 3 columns]

# %% [markdown]
# ### Tourism
# **Question:**
# _I would welcome visitors from: (Check all that appy)_

# %% [markdown]
# Same process as before

# %%
tourism = df_long.loc[df_long['Topic'] == 'Tourism '].copy()
tourism_exp = tourism['Answer'].dropna().str.split('|', expand=True)
tourism_exp['id'] = tourism_exp.index
tourism_exp.head()
# Out:
#                                    0            1                           2  \
# 5464  Nearby BC communities            All of BC    Other Canadian provinces
# 5465  Nearby BC communities            All of BC    Other Canadian provinces
# 5466  Nearby BC communities            All of BC    Other Canadian provinces
# 5467  Nearby BC communities            All of BC    Other Canadian provinces
# 5468  Nearby BC communities            All of BC    Other Canadian provinces
#
#                                3                 4    id
# 5464   United States of America    Other countries  5464
# 5465   United States of America    Other countries  5465
# 5466   United States of America    Other countries  5466
# 5467   United States of America    Other countries  5467
# 5468   United States of America    Other countries  5468

# %%
tourism_long = pd.melt(tourism_exp, id_vars=['id'], var_name='Topic', value_name='Answer')
tourism_long['Topic'] = 'Tourism'
tourism_long = tourism_long[~tourism_long['Answer'].isna()]
tourism_long['Answer'] = tourism_long['Answer'].str.strip()
tourism_long
# Out:
#         id    Topic                 Answer
# 0     5464  Tourism  Nearby BC communities
# 1     5465  Tourism  Nearby BC communities
# 2     5466  Tourism  Nearby BC communities
# 3     5467  Tourism  Nearby BC communities
# 4     5468  Tourism  Nearby BC communities
# ...    ...      ...                    ...
# 5189  6816  Tourism        Other countries
# 5190  6819  Tourism        Other countries
# 5192  6822  Tourism        Other countries
# 5193  6823  Tourism        Other countries
# 5194  6824  Tourism        Other countries
#
# [4080 rows x 3 columns]

# %% [markdown]
# ### Satisfaction with tourism .1

# %%
df_long[df_long['Topic'] == 'Satisfaction with tourism .1']['Answer'].unique()
# Out:
# array(['Increase ', nan, 'Stay the same ', 'I do not have an opinion.',
#        'Decrease', '特に意見はない', 'Meningkat'], dtype=object)

# %%
satisfaction = df_long.loc[(df_long['Topic'] == 'Satisfaction with tourism .1') & (df_long['Answer']\
    .isin(['Increase ', 'Stay the same ', 'I do not have an opinion.','Decrease']))].copy()
satisfaction
# Out:
#         id                         Topic                     Answer
# 4095     0  Satisfaction with tourism .1                  Increase
# 4097     2  Satisfaction with tourism .1                  Increase
# 4099     4  Satisfaction with tourism .1                  Increase
# 4100     5  Satisfaction with tourism .1             Stay the same
# 4102     7  Satisfaction with tourism .1                  Increase
# ...    ...                           ...                        ...
# 5454  1359  Satisfaction with tourism .1             Stay the same
# 5455  1360  Satisfaction with tourism .1                  Increase
# 5457  1362  Satisfaction with tourism .1             Stay the same
# 5458  1363  Satisfaction with tourism .1  I do not have an opinion.
# 5459  1364  Satisfaction with tourism .1  I do not have an opinion.
#
# [1035 rows x 3 columns]

# %% [markdown]
# ### Combine with dataset

# %%
df_long_updated = df_long.loc[~(df_long['Topic'].isin(['Satisfaction with tourism .1', 'Tourism ', 'Jobs with tourism ']))]
df_long_updated = df_long_updated.append([satisfaction, jobs_long, tourism_long])

# %%
df_long_updated[df_long_updated['Topic'] == 'Jobs with tourism']['Answer'].value_counts()
# Out:
# British Columbia Visitors    941
# Canadian Visitors            858
# Other countries              719
# United States of America     678
# Name: Answer, dtype: int64

# %%
df_long_updated['Topic'] = df_long_updated['Topic'].str.strip()

# %% [markdown]
# ## 3) Add questions to dataset
# Load corresponding sheet from workbook, join by topic

# %%
sheet_name = 'questions_table'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

question_data = pd.read_csv(url)
question_data['Topic'] = question_data['Topic'].str.strip()
question_data
# Out:
#                                                 Topic  \
# 0                              Satisfaction with life
# 1                     Sense of belonging in community
# 2                           Satisfaction with tourism
# 3                           Satisfaction with tourism
# 4                                             Tourism
# 5                                   Jobs with tourism
# 6                       Entrepreneurship with tourism
# 7                          Local culture from tourism
# 8        Production of local productions with tourism
# 9                        Views on policies on tourism
# 10  Satisfaction with the quality of basic educati...
# 11  Satisfaction with the quality of basic healh s...
# 12             Satisfaction with access to recreation
# 13    Satisfaction with access to cultural activities
# 14                           Satisfaction with safety
# 15                     Sense of a healthy environment
#
#                                              Question
# 0   Overall, how satisfied are you with your life ...
# 1   How would you describe your feeling of belongi...
# 2   How satisfied are you with the state of touris...
# 3   Overall, the number of tourists to my site sho...
# 4   I would welcome visitors from: (Check all that...
# 5   If you saw an advertisement promoting your reg...
# 6   Tourism creates jobs for local people at my site.
# 7   Tourism promotes local entrepreneurship at my ...
# 8      Tourism promotes the local culture at my site.
# 9   Tourism promotes production of local products ...
# 10  There are policies, strategies and programs th...
# 11  Do you agree with the following statement:  I ...
# 12  Your access to sports and recreational activit...
# 13   Your access to artistic and cultural activities?
# 14  How satisfied are you with your personal safet...
# 15          How healthy is your physical environment?

# %%
df_long_updated.Topic.unique()
# Out:
# array(['Satisfaction with life', 'Sense of belonging in community',
#        'Satisfaction with tourism', 'Entrepreneurship with tourism',
#        'Local culture from tourism',
#        'Production of local productions with tourism',
#        'Views on policies on tourism',
#        'Satisfaction with the quality of basic educational services',
#        'Satisfaction with the quality of basic healh services',
#        'Satisfaction with access to recreation',
#        'Satisfaction with access to cultural activities',
#        'Satisfaction with safety', 'Sense of a healthy environment',
#        'Satisfaction with tourism .1', 'Jobs with tourism', 'Tourism'],
#       dtype=object)

# %%
question_data.iloc[3]['Topic'] = 'Satisfaction with tourism .1'
question_data
# Out:
#                                                 Topic  \
# 0                              Satisfaction with life
# 1                     Sense of belonging in community
# 2                           Satisfaction with tourism
# 3                        Satisfaction with tourism .1
# 4                                             Tourism
# 5                                   Jobs with tourism
# 6                       Entrepreneurship with tourism
# 7                          Local culture from tourism
# 8        Production of local productions with tourism
# 9                        Views on policies on tourism
# 10  Satisfaction with the quality of basic educati...
# 11  Satisfaction with the quality of basic healh s...
# 12             Satisfaction with access to recreation
# 13    Satisfaction with access to cultural activities
# 14                           Satisfaction with safety
# 15                     Sense of a healthy environment
#
#                                              Question
# 0   Overall, how satisfied are you with your life ...
# 1   How would you describe your feeling of belongi...
# 2   How satisfied are you with the state of touris...
# 3   Overall, the number of tourists to my site sho...
# 4   I would welcome visitors from: (Check all that...
# 5   If you saw an advertisement promoting your reg...
# 6   Tourism creates jobs for local people at my site.
# 7   Tourism promotes local entrepreneurship at my ...
# 8      Tourism promotes the local culture at my site.
# 9   Tourism promotes production of local products ...
# 10  There are policies, strategies and programs th...
# 11  Do you agree with the following statement:  I ...
# 12  Your access to sports and recreational activit...
# 13   Your access to artistic and cultural activities?
# 14  How satisfied are you with your personal safet...
# 15          How healthy is your physical environment?

# %%
df_long = pd.merge(df_long_updated, question_data, on='Topic', how='left')
df_long
# Out:
#          id                   Topic           Answer  \
# 0         0  Satisfaction with life               80
# 1         1  Satisfaction with life               60
# 2         2  Satisfaction with life               80
# 3         3  Satisfaction with life               70
# 4         4  Satisfaction with life               70
# ...     ...                     ...              ...
# 26051  6816                 Tourism  Other countries
# 26052  6819                 Tourism  Other countries
# 26053  6822                 Tourism  Other countries
# 26054  6823                 Tourism  Other countries
# 26055  6824                 Tourism  Other countries
#
#                                                 Question
# 0      Overall, how satisfied are you with your life ...
# 1      Overall, how satisfied are you with your life ...
# 2      Overall, how satisfied are you with your life ...
# 3      Overall, how satisfied are you with your life ...
# 4      Overall, how satisfied are you with your life ...
# ...                                                  ...
# 26051  I would welcome visitors from: (Check all that...
# 26052  I would welcome visitors from: (Check all that...
# 26053  I would welcome visitors from: (Check all that...
# 26054  I would welcome visitors from: (Check all that...
# 26055  I would welcome visitors from: (Check all that...
#
# [26056 rows x 4 columns]

# %% [markdown]
# ## 4) Save data
# The dataset is ready for use in visualizations (Tableau or Python) or for further formatting for the API when the data model is ready

# %%
df_long.to_csv('../data/local_satisfaction_long_data.csv', index=False)
